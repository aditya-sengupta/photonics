# %%
import numpy as np
import matplotlib.pyplot as plt
import hcipy
print(f"hcipy version {hcipy.__version__}")
from hcipy.mode_basis import zernike_ansi
# Out:
# hcipy version 0.5.1

# %% [markdown]
# Not importing Lightbeam here so this is more portable/so we just look at the hcipy bit, but the Lightbeam-imposed constraint is: we want to couple light into a fiber of radius 10 microns on a grid that's 256 microns wide (plus a slight expansion for the PML method.)

# %%
ds = 0.25 # um
PML = int(4 / ds) # "perfectly matched layers": how much to expand the grid to damp evanescent waves
xyr = np.arange(-132.0, 132.0+ds, ds) # um
# -128 to +128 for physical purposes and +4 on both ends for the PML
xg, yg = np.meshgrid(xyr, xyr, indexing='ij')
rclad = 10.0 # um
wl = 1.55 # um

# %%
mask = xg ** 2 + yg ** 2 <= rclad ** 2
plt.imshow(mask, extent=(np.min(xg), np.max(xg), np.min(yg), np.max(yg)))
plt.xlabel("x (um)")
plt.ylabel("y (um)");

# %%
s = 2 * rclad / ds + 1 # image diameter in pixels
q = 16 # pixels per resolution element
D = 3.0 # m; Shane
f = 51.0 # m; Shane
d = int((xg.shape[0] - s) // 2) # padding in the focal plane
pupil_grid = hcipy.make_pupil_grid(dims=xg.shape, diameter=D)
focal_grid = hcipy.make_focal_grid(q = q, num_airy = (s / 2) / q, spatial_resolution = ds * 1e-6)
fprop = hcipy.FraunhoferPropagator(pupil_grid, focal_grid)

def field_at_focal_plane(zern, amp):
    phase = zernike_ansi(zern)(pupil_grid)
    aberration = np.exp(1j * amp * phase)
    wf = hcipy.Wavefront(aberration, wavelength=wl)
    u = np.array(fprop(wf).electric_field.shaped)
    u = np.pad(u, ((d, d), (d, d))) * mask
    return u

# %%
plt.imshow(np.abs(field_at_focal_plane(5, 1.0)), extent=(np.min(xg), np.max(xg), np.min(yg), np.max(yg)))
plt.colorbar()
plt.xlabel("x (um)")
plt.ylabel("y (um)");
# this should be the same as the mask (seems good)

# %%
plt.imshow(np.angle(field_at_focal_plane(5, 1.0))[d:-d, d:-d], extent=(-rclad, rclad, -rclad, rclad))
plt.title("Phase in the focal plane")
plt.colorbar()
plt.xlabel("x (um)")
plt.ylabel("y (um)");
# This seems to not be doing anything, so something's wrong
# Is this a reasonable thing to look at, 
# or do I want to use some other quantity to visualize what's going into lightbeam?
# And what needs to change in the preceding steps?
